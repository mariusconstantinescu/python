# %% [markdown]
# <a href="https://colab.research.google.com/github/mariusconstantinescu/python/blob/master/guessing_game_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tested in Jupyter Lab.
import random
from IPython.display import clear_output


print(" Computer generated an integer from the interval 0 - 100. You have 10 trials to guess it.")

def guessing_game():
    guess_computer = random.randint(0, 100)
        
    for x in range(11):       
                
        try:
          
            guess_user = int(input(" Guess the number generated by the computer: "))

            if guess_computer == guess_user:
                print(f" Your entry of {guess_user} was just right. Program is now closed.")
                break

            elif guess_computer > guess_user:
                clear_output()
                print(f" Your entry of {guess_user} was too low. Please try a new number. ")
                
            elif guess_computer < guess_user:
                clear_output()
                print(f" Your entry of {guess_user} was too high. Please try a new number. ")
                
                
        except:
            print(" There was an error. Please check if your entry is an integer from 0-100. Your entry was not an integer")
            break
    
    else:
        print(f" You had more than 10 trials. Game over. The solution was: {guess_computer}")
            
guessing_game()
